# %%
# Imports math library
import numpy as np
# Imports plotting library
import matplotlib.pyplot as plt
# Define a linear function with just one input, x
def linear_function_1D(x,beta,omega):
  # TODO -- replace the code line below with formula for 1D linear equation
  y = beta + omega * x
  return y
  # Plot the 1D linear function

# Define an array of x values from 0 to 10 with increments of 0.01
# https://numpy.org/doc/stable/reference/generated/numpy.arange.html
x = np.arange(0.0,20.0, 0.01)
# Compute y using the function you filled in above
beta = 10.0; omega = -2.0

y = linear_function_1D(x,beta,omega)

# Plot this function
fig, ax = plt.subplots()
ax.plot(x,y,'r-')
ax.set_ylim([0,10]);ax.set_xlim([0,10])
ax.set_xlabel('x'); ax.set_ylabel('y')
plt.show()

# TODO -- experiment with changing the values of beta and omega
# to understand what they do.  Try to make a line
# that crosses the y-axis at y=10 and the x-axis at x=5

# Define a linear function with two inputs, x1 and x2
def linear_function_2D(x1,x2,beta,omega1,omega2):
  # TODO -- replace the code line below with formula for 2D linear equation
  #ax + by + c = 0
  y = beta + omega1 * x1 + omega2 * x2
  return y

def draw_2D_function(x1_mesh, x2_mesh, y):
    fig, ax = plt.subplots()
    fig.set_size_inches(7,7)
    pos = ax.contourf(x1_mesh, x2_mesh, y, levels=256 ,cmap = 'hot', vmin=-10,vmax=10.0)
    fig.colorbar(pos, ax=ax)
    ax.set_xlabel('x1');ax.set_ylabel('x2')
    levels = np.arange(-10,10,1.0)
    ax.contour(x1_mesh, x2_mesh, y, levels, cmap='winter')
    plt.show()
    # Define a linear function with two inputs, x1 and x2
def linear_function_2D(x1,x2,beta,omega1,omega2):
  # TODO -- replace the code line below with formula for 2D linear equation
  #ax + by + c = 0
  y = beta + omega1 * x1 + omega2 * x2
  return y

  # Plot the 2D function

# Make 2D array of x and y points
x1 = np.arange(0.0, 10.0, 0.1)
x2 = np.arange(0.0, 10.0, 0.1)
x1,x2 = np.meshgrid(x1,x2)  # https://www.geeksforgeeks.org/numpy-meshgrid-function/

# Compute the 2D function for given values of omega1, omega2
beta = 0.0; omega1 = 0; omega2 = -0.5
y  = linear_function_2D(x1,x2,beta, omega1, omega2)

# Draw the function.
# Color represents y value (brighter = higher value)
# Black = -10 or less, White = +10 or more
# 0 = mid orange
# Lines are contours where value is equal
draw_2D_function(x1,x2,y)

# TODO
# Predict what this plot will look like if you set omega_1 to zero
# Change the code and see if you are right.
# What happened was eplain why the lines turned diagonal from red to yellow
#diagonally to red to dark red to red horizonatlly since

# TODO
# Predict what this plot will look like if you set omega_2 to zero
# Change the code and see if you are right.
#what happened was that the graph was dark red with horizontal lines and it
#turned into orange and there were no lines.

# TODO
# Predict what this plot will look like if you set beta to -5
# Change the code and see if you are correct
# after changing the code, the graph turned into a dark red with black,
# with horizontal lines

# Define a linear function with three inputs, x1, x2, and x_3
def linear_function_3D(x1,x2,x3,beta,omega1,omega2,omega3):
  # TODO -- replace the code below with formula for a single 3D linear equation
   y = beta + omega1 * x1 + omega2 * x2 + omega3 * x3

  return y

  #questions 1. 1.  A single linear equation with three inputs
  # (i.e. **linear_function_3D()**) associates a value y with each point in a 3D
  # space ($x_1$,$x_2$,$x_3$).  Is it possible to visualize this?   What value
   # is at position (0,0,0)?
   #  you can use 2D slices or
   # 3D plots with color to represent an output. The value at (0,0,0) is  the
   # intercept at B.

   #question 2. x1 = 2.0
  #x2 = 3.0

  # Define coefficients for three equations
  #beta1, beta2, beta3 = 1.0, 2.0, 3.0
  ##omega11, omega12 = 0.5, 1.0
  #omega21, omega22 = 1.5, -0.5
 # omega31, omega32 = -1.0, 2.0

#y1 = beta1 + omega11 * x1 + omega12 * x2
#y2 = beta2 + omega21 * x1 + omega22 * x2
#y3 = beta3 + omega31 * x1 + omega32 * x2

#print(f"y1 = {y1}, y2 = {y2}, y3 = {y3}")

# Questions

#1. What is exp[0]?  e^0 = 1
#2. What is exp[1]? e^1 = 2.718
#3. What is exp[-\infty]? e^-inf = 0
#4. What is exp[+\infty]? e ^ inf = inf
#5. A function is convex if we can draw a straight
#line between any two points on the function, and the
#line lies above the function everywhere between these
#two points. Similarly, a function is concave if a straight
#line between any two points lies below the function everywhere
#between these two points.  Is the exponential function convex or concave or neither?
# I think that y = exp[x] is is convex because any 2 points that are connecting them fall
#above the line

# Questions

#1. What is log[0]?  --> log base 0 = undefined
#2. What is log[1]? log[1] = 0
#3. What is log[e]? log[e] = 1
#4. What is log[exp[3]]? --> log[exp[3]]=3
#5. What is exp[log[4]? --> exp[log[4]]=4
#6. What is log[-1]? --> undefined
#7. Is the logarithm function concave or convex? --> logs are always concave
